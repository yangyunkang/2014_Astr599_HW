# %%
import numpy as np

# %%
from numpy import genfromtxt

# %%
my_data = np.genfromtxt('https://raw.githubusercontent.com/jakevdp/2014_fall_ASTR599/master/notebooks/data/asteroids5000.csv',delimiter=',',skip_header=1)

# %%
my_data
# Out:
# array([[  2.76680727e+00,   7.57972598e-02,   1.05939814e+01, ...,
#           9.52400000e+02,   7.13000000e-01,   4.26000000e-01],
#        [  2.77243388e+00,   2.31565012e-01,   3.48362566e+01, ...,
#           5.45000000e+02,   6.35000000e-01,   2.84000000e-01],
#        [  2.67030537e+00,   2.55287122e-01,   1.29805794e+01, ...,
#           2.33920000e+02,   8.24000000e-01,   4.33000000e-01],
#        ...,
#        [  2.68414124e+00,   2.07573312e-01,   6.45590489e+00, ...,
#                      nan,              nan,              nan],
#        [  2.60526964e+00,   1.24151564e-01,   1.19219429e+01, ...,
#                      nan,              nan,              nan],
#        [  3.01427904e+00,   8.02323462e-02,   1.03726702e+01, ...,
#                      nan,              nan,              nan]])

# %%
np.isnan(my_data).sum()
# Out:
# 11241

# %%
my_data[1]
# Out:
# array([  2.77243388e+00,   2.31565012e-01,   3.48362566e+01,
#          4.13000000e+00,   5.45000000e+02,   6.35000000e-01,
#          2.84000000e-01])

# %%
my_data.shape
# Out:
# (5000, 7)

# %%
np.isnan(my_data).sum?
nu = np.sum(np.isnan(my_data),1)
nu

# %%
mask = (nu==0)
len(nu[mask])
# Out:
# 767

# %%
my_data[mask].shape
new = my_data[mask]
np.mean(new,0)
# Out:
# array([  2.84852694,   0.13989068,   9.74426393,   9.26473272,
#         78.08349413,   0.75930769,   0.35792047])

# %%
# %matplotlib inline

import matplotlib

import matplotlib.pyplot as plt

i = np.sin(np.radians((new[:,2])))
C = (new[:,5]>0.8)
plt.scatter(new[:,0], i,c=C)

# %%
plt.scatter(new[:,3], new[:,5])

# %%
x = [0,4,8,12]
y = [0.8,0.8,0.8,0.8]
plt.plot(x,y)
C = (new[:,5]>0.8)
plt.scatter(new[:,3], new[:,5], c = C,)
plt.scatter?

# %%
np.sin?

# %%
np.isnan(my_data).sum

# %%
np.isnan(my_data).sum

# %%
np.isnan(my_data).sum

# %%
my_data.shape
# Out:
# (5000, 7)

# %%
mask = (my_data != np.nan)
mask
my_data2 = my_data[mask]
my_data
# Out:
# array([[  2.76680727e+00,   7.57972598e-02,   1.05939814e+01, ...,
#           9.52400000e+02,   7.13000000e-01,   4.26000000e-01],
#        [  2.77243388e+00,   2.31565012e-01,   3.48362566e+01, ...,
#           5.45000000e+02,   6.35000000e-01,   2.84000000e-01],
#        [  2.67030537e+00,   2.55287122e-01,   1.29805794e+01, ...,
#           2.33920000e+02,   8.24000000e-01,   4.33000000e-01],
#        ...,
#        [  2.68414124e+00,   2.07573312e-01,   6.45590489e+00, ...,
#                      nan,              nan,              nan],
#        [  2.60526964e+00,   1.24151564e-01,   1.19219429e+01, ...,
#                      nan,              nan,              nan],
#        [  3.01427904e+00,   8.02323462e-02,   1.03726702e+01, ...,
#                      nan,              nan,              nan]])

# %%
for i in my_data.rows:
    for j in x.cols:
       if x[i,j] = np.nan

# %%
np.head (my_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-8d0c80b42c0d> in <module>()
# ----> 1 np.head (my_data)
#
# AttributeError: 'module' object has no attribute 'head'

# %%
my_data[np.isnan(my_data)] = 0
my_data.sum(1)
# Out:
# array([ 970.31558595,  587.88925546,  256.41317189, ...,   22.04761944,
#          26.55136411,   25.56718158])

# %%
my_data[my_data != np.nan]
# Out:
# array([  2.76680727,   0.07579726,  10.59398142, ...,          nan,
#                 nan,          nan])

# %%
cd
# Out:
# /Users/yunkangyang

# %%
pdw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a7b477cf3433> in <module>()
# ----> 1 pdw
#
# NameError: name 'pdw' is not defined

# %%
$ipython locate
# Out:
#   File "<ipython-input-23-85819c507535>", line 1
#     $ipython locate
#     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline

import matplotlib

import matplotlib.pyplot as plt
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `"asteroids5000.csv.text"'
# /bin/sh: -c: line 0: `head ("asteroids5000.csv.text")'

# %%
plt.scatter(new)
